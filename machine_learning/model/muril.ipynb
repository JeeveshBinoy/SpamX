# %% [markdown]
# 0.IMPORTS

# %%
import os
import time
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
from datasets import Dataset
from datetime import timedelta
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from transformers import (
    AutoTokenizer, 
    AutoModelForSequenceClassification, 
    TrainingArguments, 
    Trainer,
    DataCollatorWithPadding,
    EarlyStoppingCallback, 
    TrainerCallback
)

# %% [markdown]
# 1. PATHS & INITIAL CONFIGURATION

# %%
MODEL_NAME = "google/muril-base-cased" 
TRAIN_PATH = r'D:\Major Project\SpamX\machine_learning\dataset\train.csv'
VAL_PATH = r'D:\Major Project\SpamX\machine_learning\dataset\validation.csv'
OUTPUT_DIR = r'D:\Major Project\SpamX\machine_learning\models\MuRIL'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# c:\Users\jeeve\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# 2. ETA & PROGRESS LOGGING

# %%
class ETALoggingCallback(TrainerCallback):
    def __init__(self):
        self.start_time = None

    def on_train_begin(self, args, state, control, **kwargs):
        self.start_time = time.time()
        print(f"\nMuRIL Finetuning Started | Total Steps: {state.max_steps}")

    def on_log(self, args, state, control, logs=None, **kwargs):
        if self.start_time and state.global_step > 0:
            elapsed = time.time() - self.start_time
            avg_time_per_step = elapsed / state.global_step
            remaining_steps = state.max_steps - state.global_step
            eta_seconds = remaining_steps * avg_time_per_step
            
            eta_str = str(timedelta(seconds=int(eta_seconds)))
            raw_loss = logs.get("loss", "N/A")
            loss_val = f"{raw_loss:.4f}" if isinstance(raw_loss, (float, int)) else "Calculating..."
            
            print(f"Step: {state.global_step}/{state.max_steps} | Loss: {loss_val} | ETA: {eta_str} | Progress: {(state.global_step/state.max_steps)*100:.2f}%")

# %% [markdown]
# 3. SLIDING WINDOW

# %%
def tokenize_comment_only(examples):
    texts = [str(com) for com in examples["Comment"]]
    
    tokenized = tokenizer(
        texts,
        truncation=True,
        max_length=128, 
        stride=32,     
        return_overflowing_tokens=True,
        padding="max_length"
    )
    
    sample_mapping = tokenized.pop("overflow_to_sample_mapping")
    tokenized["labels"] = [examples["Label"][i] for i in sample_mapping]
    return tokenized

# %% [markdown]
# 4. METRICS

# %%
class FocalLossTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        
        gamma, alpha = 2.0, 0.25 
        probs = F.softmax(logits, dim=-1)
        pt = probs.gather(1, labels.unsqueeze(1)).squeeze(1)
        
        loss = -alpha * (1 - pt) ** gamma * (pt + 1e-8).log()
        return (loss.mean(), outputs) if return_outputs else loss.mean()

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {
        "accuracy": accuracy_score(labels, predictions),
        "f1": f1_score(labels, predictions),
        "precision": precision_score(labels, predictions),
        "recall": recall_score(labels, predictions)
    }

# %% [markdown]
# 5. DATA LOADING & PREPARATION

# %%
train_df = pd.read_csv(TRAIN_PATH)
val_df = pd.read_csv(VAL_PATH)

train_ds = Dataset.from_pandas(train_df).map(
    tokenize_comment_only, batched=True, remove_columns=train_df.columns.tolist()
)
val_ds = Dataset.from_pandas(val_df).map(
    tokenize_comment_only, batched=True, remove_columns=val_df.columns.tolist()
)
# Out:
# Map:   0%|          | 0/61645 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6438 [00:00<?, ? examples/s]

# %% [markdown]
# 6. MODEL INITIALIZATION & FINETUNING

# %%
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2).to(device)

training_args = TrainingArguments(
    output_dir=os.path.join(OUTPUT_DIR, "checkpoints"),
    num_train_epochs=3,
    per_device_train_batch_size=16,
    learning_rate=2e-5,
    logging_steps=50,
    evaluation_strategy="steps",
    eval_steps=500,
    save_strategy="steps",
    save_steps=500,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    fp16=True,
    report_to="none",
    disable_tqdm=True
)

trainer = FocalLossTrainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    compute_metrics=compute_metrics,
    data_collator=DataCollatorWithPadding(tokenizer=tokenizer),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2), ETALoggingCallback()]
)

trainer.train()
# Out:
# c:\Users\jeeve\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google/muril-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# MuRIL Finetuning Started | Total Steps: 11697
# Step: 50/11697 | Loss: 0.0403 | ETA: 0:37:44 | Progress: 0.43%
# {'loss': 0.0403, 'grad_norm': 0.05900135263800621, 'learning_rate': 1.991450799350261e-05, 'epoch': 0.012823800974608874}
# Step: 100/11697 | Loss: 0.0300 | ETA: 0:36:23 | Progress: 0.85%
# {'loss': 0.03, 'grad_norm': 0.06310241669416428, 'learning_rate': 1.9829015987005217e-05, 'epoch': 0.02564760194921775}
# Step: 150/11697 | Loss: 0.0209 | ETA: 0:35:51 | Progress: 1.28%
# {'loss': 0.0209, 'grad_norm': 0.07979048788547516, 'learning_rate': 1.9743523980507824e-05, 'epoch': 0.03847140292382662}
# Step: 200/11697 | Loss: 0.0163 | ETA: 0:35:31 | Progress: 1.71%
# {'loss': 0.0163, 'grad_norm': 0.04546665400266647, 'learning_rate': 1.9658031974010432e-05, 'epoch': 0.0512952038984355}
# Step: 250/11697 | Loss: 0.0131 | ETA: 0:35:22 | Progress: 2.14%
# {'loss': 0.0131, 'grad_norm': 0.06668771058320999, 'learning_rate': 1.957253996751304e-05, 'epoch': 0.06411900487304437}
# Step: 300/11697 | Loss: 0.0150 | ETA: 0:36:26 | Progress: 2.56%
# {'loss': 0.015, 'grad_norm': 0.0764201208949089, 'learning_rate': 1.9487047961015647e-05, 'epoch': 0.07694280584765324}
# Step: 350/11697 | Loss: 0.0115 | ETA: 0:36:38 | Progress: 2.99%
# {'loss': 0.0115, 'grad_norm': 0.1222395971417427, 'learning_rate': 1.9401555954518255e-05, 'epoch': 0.08976660682226212}
# Step: 400/11697 | Loss: 0.0141 | ETA: 0:36:18 | Progress: 3.42%
# {'loss': 0.0141, 'grad_norm': 0.10724318772554398, 'learning_rate': 1.9316063948020862e-05, 'epoch': 0.102590407796871}
# Step: 450/11697 | Loss: 0.0127 | ETA: 0:36:15 | Progress: 3.85%
# {'loss': 0.0127, 'grad_norm': 0.06433093547821045, 'learning_rate': 1.923057194152347e-05, 'epoch': 0.11541420877147987}
# Step: 500/11697 | Loss: 0.0107 | ETA: 0:36:00 | Progress: 4.27%
# {'loss': 0.0107, 'grad_norm': 0.08234498649835587, 'learning_rate': 1.9145079935026077e-05, 'epoch': 0.12823800974608873}
# Step: 500/11697 | Loss: Calculating... | ETA: 0:45:44 | Progress: 4.27%
# {'eval_loss': 0.01143029797822237, 'eval_accuracy': 0.9554599907848257, 'eval_f1': 0.9530592424732923, 'eval_precision': 0.999660441426146, 'eval_recall': 0.9106093411691927, 'eval_runtime': 26.0805, 'eval_samples_per_second': 249.65, 'eval_steps_per_second': 31.211, 'epoch': 0.12823800974608873}
# Step: 550/11697 | Loss: 0.0095 | ETA: 0:46:11 | Progress: 4.70%
# {'loss': 0.0095, 'grad_norm': 0.06088836118578911, 'learning_rate': 1.9059587928528685e-05, 'epoch': 0.14106181072069762}
# Step: 600/11697 | Loss: 0.0096 | ETA: 0:45:10 | Progress: 5.13%
# {'loss': 0.0096, 'grad_norm': 0.10724552720785141, 'learning_rate': 1.8974095922031292e-05, 'epoch': 0.15388561169530648}
# Step: 650/11697 | Loss: 0.0126 | ETA: 0:44:08 | Progress: 5.56%
# {'loss': 0.0126, 'grad_norm': 0.9989272952079773, 'learning_rate': 1.88886039155339e-05, 'epoch': 0.16670941266991537}
# Step: 700/11697 | Loss: 0.0082 | ETA: 0:43:12 | Progress: 5.98%
# {'loss': 0.0082, 'grad_norm': 0.03957608342170715, 'learning_rate': 1.8803111909036507e-05, 'epoch': 0.17953321364452424}
# Step: 750/11697 | Loss: 0.0066 | ETA: 0:42:28 | Progress: 6.41%
# {'loss': 0.0066, 'grad_norm': 0.13933642208576202, 'learning_rate': 1.8717619902539115e-05, 'epoch': 0.1923570146191331}
# Step: 800/11697 | Loss: 0.0102 | ETA: 0:41:45 | Progress: 6.84%
# {'loss': 0.0102, 'grad_norm': 0.08116883039474487, 'learning_rate': 1.863212789604172e-05, 'epoch': 0.205180815593742}
# Step: 850/11697 | Loss: 0.0099 | ETA: 0:41:15 | Progress: 7.27%
# {'loss': 0.0099, 'grad_norm': 0.691149115562439, 'learning_rate': 1.854663588954433e-05, 'epoch': 0.21800461656835085}
# Step: 900/11697 | Loss: 0.0107 | ETA: 0:40:52 | Progress: 7.69%
# {'loss': 0.0107, 'grad_norm': 0.4051208794116974, 'learning_rate': 1.8461143883046938e-05, 'epoch': 0.23082841754295974}
# Step: 950/11697 | Loss: 0.0111 | ETA: 0:40:17 | Progress: 8.12%
# {'loss': 0.0111, 'grad_norm': 0.037826862186193466, 'learning_rate': 1.8375651876549545e-05, 'epoch': 0.2436522185175686}
# Step: 1000/11697 | Loss: 0.0089 | ETA: 0:39:48 | Progress: 8.55%
# {'loss': 0.0089, 'grad_norm': 0.042389821261167526, 'learning_rate': 1.829015987005215e-05, 'epoch': 0.25647601949217746}
# Step: 1000/11697 | Loss: Calculating... | ETA: 0:44:28 | Progress: 8.55%
# {'eval_loss': 0.008355810306966305, 'eval_accuracy': 0.9599139917063431, 'eval_f1': 0.9583133684714902, 'eval_precision': 0.9907529722589168, 'eval_recall': 0.9279307145066502, 'eval_runtime': 26.1865, 'eval_samples_per_second': 248.64, 'eval_steps_per_second': 31.085, 'epoch': 0.25647601949217746}
# Step: 1050/11697 | Loss: 0.0082 | ETA: 0:44:35 | Progress: 8.98%
# {'loss': 0.0082, 'grad_norm': 0.5475983619689941, 'learning_rate': 1.820466786355476e-05, 'epoch': 0.26929982046678635}
# Step: 1100/11697 | Loss: 0.0099 | ETA: 0:43:51 | Progress: 9.40%
# {'loss': 0.0099, 'grad_norm': 0.09866049885749817, 'learning_rate': 1.8119175857057368e-05, 'epoch': 0.28212362144139524}
# Step: 1150/11697 | Loss: 0.0066 | ETA: 0:43:09 | Progress: 9.83%
# {'loss': 0.0066, 'grad_norm': 0.40322571992874146, 'learning_rate': 1.8033683850559972e-05, 'epoch': 0.2949474224160041}
# Step: 1200/11697 | Loss: 0.0090 | ETA: 0:42:35 | Progress: 10.26%
# {'loss': 0.009, 'grad_norm': 0.2268361896276474, 'learning_rate': 1.794819184406258e-05, 'epoch': 0.30777122339061297}
# Step: 1250/11697 | Loss: 0.0085 | ETA: 0:41:58 | Progress: 10.69%
# {'loss': 0.0085, 'grad_norm': 0.08908736705780029, 'learning_rate': 1.786269983756519e-05, 'epoch': 0.32059502436522186}
# Step: 1300/11697 | Loss: 0.0103 | ETA: 0:41:25 | Progress: 11.11%
# {'loss': 0.0103, 'grad_norm': 0.12806901335716248, 'learning_rate': 1.7777207831067798e-05, 'epoch': 0.33341882533983075}
# Step: 1350/11697 | Loss: 0.0095 | ETA: 0:41:03 | Progress: 11.54%
# {'loss': 0.0095, 'grad_norm': 1.0771784782409668, 'learning_rate': 1.7691715824570402e-05, 'epoch': 0.3462426263144396}
# Step: 1400/11697 | Loss: 0.0081 | ETA: 0:40:42 | Progress: 11.97%
# {'loss': 0.0081, 'grad_norm': 0.09817507863044739, 'learning_rate': 1.7606223818073013e-05, 'epoch': 0.3590664272890485}
# Step: 1450/11697 | Loss: 0.0062 | ETA: 0:40:14 | Progress: 12.40%
# {'loss': 0.0062, 'grad_norm': 0.01923413760960102, 'learning_rate': 1.7522441651705566e-05, 'epoch': 0.37189022826365736}
# Step: 1500/11697 | Loss: 0.0081 | ETA: 0:39:44 | Progress: 12.82%
# {'loss': 0.0081, 'grad_norm': 0.18768633902072906, 'learning_rate': 1.7436949645208174e-05, 'epoch': 0.3847140292382662}
# Step: 1500/11697 | Loss: Calculating... | ETA: 0:43:07 | Progress: 12.82%
# {'eval_loss': 0.008674629963934422, 'eval_accuracy': 0.959146060512978, 'eval_f1': 0.9570967741935484, 'eval_precision': 1.0, 'eval_recall': 0.917723476647077, 'eval_runtime': 29.9341, 'eval_samples_per_second': 217.511, 'eval_steps_per_second': 27.193, 'epoch': 0.3847140292382662}
# Step: 1550/11697 | Loss: 0.0073 | ETA: 0:43:02 | Progress: 13.25%
# {'loss': 0.0073, 'grad_norm': 0.05158175528049469, 'learning_rate': 1.735145763871078e-05, 'epoch': 0.3975378302128751}
# Step: 1600/11697 | Loss: 0.0068 | ETA: 0:42:30 | Progress: 13.68%
# {'loss': 0.0068, 'grad_norm': 0.2539606988430023, 'learning_rate': 1.726596563221339e-05, 'epoch': 0.410361631187484}
# Step: 1650/11697 | Loss: 0.0084 | ETA: 0:41:56 | Progress: 14.11%
# {'loss': 0.0084, 'grad_norm': 0.13652625679969788, 'learning_rate': 1.7182183465845945e-05, 'epoch': 0.42318543216209287}
# Step: 1700/11697 | Loss: 0.0084 | ETA: 0:41:25 | Progress: 14.53%
# {'loss': 0.0084, 'grad_norm': 0.12258481234312057, 'learning_rate': 1.7096691459348553e-05, 'epoch': 0.4360092331367017}
# Step: 1750/11697 | Loss: 0.0089 | ETA: 0:40:55 | Progress: 14.96%
# {'loss': 0.0089, 'grad_norm': 0.0970810279250145, 'learning_rate': 1.701119945285116e-05, 'epoch': 0.4488330341113106}
# Step: 1800/11697 | Loss: 0.0088 | ETA: 0:40:25 | Progress: 15.39%
# {'loss': 0.0088, 'grad_norm': 0.09958289563655853, 'learning_rate': 1.6925707446353768e-05, 'epoch': 0.4616568350859195}
# Step: 1850/11697 | Loss: 0.0102 | ETA: 0:39:57 | Progress: 15.82%
# {'loss': 0.0102, 'grad_norm': 0.5620465874671936, 'learning_rate': 1.6840215439856376e-05, 'epoch': 0.4744806360605283}
# Step: 1900/11697 | Loss: 0.0079 | ETA: 0:39:29 | Progress: 16.24%
# {'loss': 0.0079, 'grad_norm': 0.03021986596286297, 'learning_rate': 1.675472343335898e-05, 'epoch': 0.4873044370351372}
# Step: 1950/11697 | Loss: 0.0072 | ETA: 0:39:03 | Progress: 16.67%
# {'loss': 0.0072, 'grad_norm': 0.02814258635044098, 'learning_rate': 1.666923142686159e-05, 'epoch': 0.500128238009746}
# Step: 2000/11697 | Loss: 0.0079 | ETA: 0:38:39 | Progress: 17.10%
# {'loss': 0.0079, 'grad_norm': 0.0563305988907814, 'learning_rate': 1.65837394203642e-05, 'epoch': 0.5129520389843549}
# Step: 2000/11697 | Loss: Calculating... | ETA: 0:40:49 | Progress: 17.10%
# {'eval_loss': 0.007600218523293734, 'eval_accuracy': 0.9603747504223622, 'eval_f1': 0.9588254069581871, 'eval_precision': 0.9904385097263435, 'eval_recall': 0.9291679554593257, 'eval_runtime': 26.795, 'eval_samples_per_second': 242.993, 'eval_steps_per_second': 30.379, 'epoch': 0.5129520389843549}
# Step: 2050/11697 | Loss: 0.0073 | ETA: 0:40:41 | Progress: 17.53%
# {'loss': 0.0073, 'grad_norm': 0.1790793240070343, 'learning_rate': 1.6498247413866806e-05, 'epoch': 0.5257758399589638}
# Step: 2100/11697 | Loss: 0.0068 | ETA: 0:40:14 | Progress: 17.95%
# {'loss': 0.0068, 'grad_norm': 0.5357362031936646, 'learning_rate': 1.6412755407369413e-05, 'epoch': 0.5385996409335727}
# Step: 2150/11697 | Loss: 0.0095 | ETA: 0:39:47 | Progress: 18.38%
# {'loss': 0.0095, 'grad_norm': 0.11327780038118362, 'learning_rate': 1.632726340087202e-05, 'epoch': 0.5514234419081816}
# Step: 2200/11697 | Loss: 0.0097 | ETA: 0:39:21 | Progress: 18.81%
# {'loss': 0.0097, 'grad_norm': 0.15090131759643555, 'learning_rate': 1.624177139437463e-05, 'epoch': 0.5642472428827905}
# Step: 2250/11697 | Loss: 0.0071 | ETA: 0:38:57 | Progress: 19.24%
# {'loss': 0.0071, 'grad_norm': 0.17588044703006744, 'learning_rate': 1.6156279387877233e-05, 'epoch': 0.5770710438573994}
# Step: 2300/11697 | Loss: 0.0077 | ETA: 0:38:30 | Progress: 19.66%
# {'loss': 0.0077, 'grad_norm': 0.08082466572523117, 'learning_rate': 1.6070787381379844e-05, 'epoch': 0.5898948448320082}
# Step: 2350/11697 | Loss: 0.0105 | ETA: 0:38:04 | Progress: 20.09%
# {'loss': 0.0105, 'grad_norm': 0.2459387481212616, 'learning_rate': 1.598529537488245e-05, 'epoch': 0.602718645806617}
# Step: 2400/11697 | Loss: 0.0079 | ETA: 0:37:39 | Progress: 20.52%
# {'loss': 0.0079, 'grad_norm': 0.08090007305145264, 'learning_rate': 1.589980336838506e-05, 'epoch': 0.6155424467812259}
# Step: 2450/11697 | Loss: 0.0077 | ETA: 0:37:16 | Progress: 20.95%
# {'loss': 0.0077, 'grad_norm': 0.5295495390892029, 'learning_rate': 1.5814311361887663e-05, 'epoch': 0.6283662477558348}
# Step: 2500/11697 | Loss: 0.0073 | ETA: 0:36:52 | Progress: 21.37%
# {'loss': 0.0073, 'grad_norm': 0.1018800437450409, 'learning_rate': 1.5728819355390274e-05, 'epoch': 0.6411900487304437}
# Step: 2500/11697 | Loss: Calculating... | ETA: 0:38:23 | Progress: 21.37%
# {'eval_loss': 0.007368552498519421, 'eval_accuracy': 0.959299646751651, 'eval_f1': 0.9572649572649573, 'eval_precision': 1.0, 'eval_recall': 0.9180327868852459, 'eval_runtime': 24.7433, 'eval_samples_per_second': 263.142, 'eval_steps_per_second': 32.898, 'epoch': 0.6411900487304437}
# Step: 2550/11697 | Loss: 0.0090 | ETA: 0:38:16 | Progress: 21.80%
# {'loss': 0.009, 'grad_norm': 0.3363089859485626, 'learning_rate': 1.564332734889288e-05, 'epoch': 0.6540138497050526}
# Step: 2600/11697 | Loss: 0.0069 | ETA: 0:38:00 | Progress: 22.23%
# {'loss': 0.0069, 'grad_norm': 0.13431088626384735, 'learning_rate': 1.5557835342395486e-05, 'epoch': 0.6668376506796615}
# Step: 2650/11697 | Loss: 0.0076 | ETA: 0:37:45 | Progress: 22.66%
# {'loss': 0.0076, 'grad_norm': 0.14017154276371002, 'learning_rate': 1.5472343335898093e-05, 'epoch': 0.6796614516542703}
# Step: 2700/11697 | Loss: 0.0067 | ETA: 0:37:25 | Progress: 23.08%
# {'loss': 0.0067, 'grad_norm': 0.05494576320052147, 'learning_rate': 1.5386851329400704e-05, 'epoch': 0.6924852526288792}
# Step: 2750/11697 | Loss: 0.0085 | ETA: 0:37:04 | Progress: 23.51%
# {'loss': 0.0085, 'grad_norm': 0.210331529378891, 'learning_rate': 1.5301359322903312e-05, 'epoch': 0.7053090536034881}
# Step: 2800/11697 | Loss: 0.0071 | ETA: 0:36:45 | Progress: 23.94%
# {'loss': 0.0071, 'grad_norm': 0.5156446695327759, 'learning_rate': 1.5215867316405918e-05, 'epoch': 0.718132854578097}
# Step: 2850/11697 | Loss: 0.0082 | ETA: 0:36:24 | Progress: 24.37%
# {'loss': 0.0082, 'grad_norm': 0.2528664469718933, 'learning_rate': 1.5130375309908525e-05, 'epoch': 0.7309566555527058}
# Step: 2900/11697 | Loss: 0.0089 | ETA: 0:36:02 | Progress: 24.79%
# {'loss': 0.0089, 'grad_norm': 0.11317644268274307, 'learning_rate': 1.5044883303411133e-05, 'epoch': 0.7437804565273147}
# Step: 2950/11697 | Loss: 0.0065 | ETA: 0:35:41 | Progress: 25.22%
# {'loss': 0.0065, 'grad_norm': 0.11805462092161179, 'learning_rate': 1.4959391296913739e-05, 'epoch': 0.7566042575019236}
# Step: 3000/11697 | Loss: 0.0072 | ETA: 0:35:22 | Progress: 25.65%
# {'loss': 0.0072, 'grad_norm': 0.21017612516880035, 'learning_rate': 1.4873899290416348e-05, 'epoch': 0.7694280584765324}
# Step: 3000/11697 | Loss: Calculating... | ETA: 0:36:55 | Progress: 25.65%
# {'eval_loss': 0.0063245100900530815, 'eval_accuracy': 0.9637536476731685, 'eval_f1': 0.96224, 'eval_precision': 0.996685449121644, 'eval_recall': 0.9300958861738323, 'eval_runtime': 32.2109, 'eval_samples_per_second': 202.137, 'eval_steps_per_second': 25.271, 'epoch': 0.7694280584765324}
# Step: 3050/11697 | Loss: 0.0086 | ETA: 0:36:48 | Progress: 26.08%
# {'loss': 0.0086, 'grad_norm': 0.20873434841632843, 'learning_rate': 1.4788407283918955e-05, 'epoch': 0.7822518594511413}
# Step: 3100/11697 | Loss: 0.0070 | ETA: 0:36:25 | Progress: 26.50%
# {'loss': 0.007, 'grad_norm': 0.07304449379444122, 'learning_rate': 1.4702915277421563e-05, 'epoch': 0.7950756604257502}
# Step: 3150/11697 | Loss: 0.0074 | ETA: 0:36:04 | Progress: 26.93%
# {'loss': 0.0074, 'grad_norm': 0.33135658502578735, 'learning_rate': 1.4617423270924169e-05, 'epoch': 0.8078994614003591}
# Step: 3200/11697 | Loss: 0.0084 | ETA: 0:35:42 | Progress: 27.36%
# {'loss': 0.0084, 'grad_norm': 0.04986949637532234, 'learning_rate': 1.4531931264426778e-05, 'epoch': 0.820723262374968}
# Step: 3250/11697 | Loss: 0.0075 | ETA: 0:35:21 | Progress: 27.78%
# {'loss': 0.0075, 'grad_norm': 0.5181816220283508, 'learning_rate': 1.4446439257929386e-05, 'epoch': 0.8335470633495768}
# Step: 3300/11697 | Loss: 0.0071 | ETA: 0:35:09 | Progress: 28.21%
# {'loss': 0.0071, 'grad_norm': 0.4583907425403595, 'learning_rate': 1.4360947251431991e-05, 'epoch': 0.8463708643241857}
# Step: 3350/11697 | Loss: 0.0066 | ETA: 0:34:50 | Progress: 28.64%
# {'loss': 0.0066, 'grad_norm': 0.2862416207790375, 'learning_rate': 1.4275455244934599e-05, 'epoch': 0.8591946652987945}
# Step: 3400/11697 | Loss: 0.0066 | ETA: 0:34:30 | Progress: 29.07%
# {'loss': 0.0066, 'grad_norm': 0.39931491017341614, 'learning_rate': 1.4189963238437208e-05, 'epoch': 0.8720184662734034}
# Step: 3450/11697 | Loss: 0.0086 | ETA: 0:34:13 | Progress: 29.49%
# {'loss': 0.0086, 'grad_norm': 0.1765332669019699, 'learning_rate': 1.4104471231939816e-05, 'epoch': 0.8848422672480123}
# Step: 3500/11697 | Loss: 0.0058 | ETA: 0:33:53 | Progress: 29.92%
# {'loss': 0.0058, 'grad_norm': 0.24623891711235046, 'learning_rate': 1.4018979225442422e-05, 'epoch': 0.8976660682226212}
# Step: 3500/11697 | Loss: Calculating... | ETA: 0:35:08 | Progress: 29.92%
# {'eval_loss': 0.006093828473240137, 'eval_accuracy': 0.9702042696974351, 'eval_f1': 0.9693232131562303, 'eval_precision': 0.9915884826916855, 'eval_recall': 0.9480358799876276, 'eval_runtime': 32.4071, 'eval_samples_per_second': 200.913, 'eval_steps_per_second': 25.118, 'epoch': 0.8976660682226212}
# Step: 3550/11697 | Loss: 0.0066 | ETA: 0:34:59 | Progress: 30.35%
# {'loss': 0.0066, 'grad_norm': 0.19546687602996826, 'learning_rate': 1.393348721894503e-05, 'epoch': 0.9104898691972301}
# Step: 3600/11697 | Loss: 0.0076 | ETA: 0:34:40 | Progress: 30.78%
# {'loss': 0.0076, 'grad_norm': 0.0457804910838604, 'learning_rate': 1.3847995212447639e-05, 'epoch': 0.923313670171839}
# Step: 3650/11697 | Loss: 0.0048 | ETA: 0:34:20 | Progress: 31.20%
# {'loss': 0.0048, 'grad_norm': 0.13603651523590088, 'learning_rate': 1.3762503205950244e-05, 'epoch': 0.9361374711464479}
# Step: 3700/11697 | Loss: 0.0068 | ETA: 0:34:01 | Progress: 31.63%
# {'loss': 0.0068, 'grad_norm': 0.06639690697193146, 'learning_rate': 1.3677011199452852e-05, 'epoch': 0.9489612721210566}
# Step: 3750/11697 | Loss: 0.0073 | ETA: 0:33:43 | Progress: 32.06%
# {'loss': 0.0073, 'grad_norm': 0.06644841283559799, 'learning_rate': 1.359151919295546e-05, 'epoch': 0.9617850730956655}
# Step: 3800/11697 | Loss: 0.0056 | ETA: 0:33:24 | Progress: 32.49%
# {'loss': 0.0056, 'grad_norm': 0.1623915135860443, 'learning_rate': 1.3506027186458069e-05, 'epoch': 0.9746088740702744}
# Step: 3850/11697 | Loss: 0.0063 | ETA: 0:33:05 | Progress: 32.91%
# {'loss': 0.0063, 'grad_norm': 0.3293849229812622, 'learning_rate': 1.3420535179960675e-05, 'epoch': 0.9874326750448833}
# Step: 3900/11697 | Loss: 0.0056 | ETA: 0:32:45 | Progress: 33.34%
# {'loss': 0.0056, 'grad_norm': 0.10447481274604797, 'learning_rate': 1.3335043173463282e-05, 'epoch': 1.000256476019492}
# Step: 3950/11697 | Loss: 0.0044 | ETA: 0:32:27 | Progress: 33.77%
# {'loss': 0.0044, 'grad_norm': 0.024917200207710266, 'learning_rate': 1.324955116696589e-05, 'epoch': 1.013080276994101}
# Step: 4000/11697 | Loss: 0.0025 | ETA: 0:32:10 | Progress: 34.20%
# {'loss': 0.0025, 'grad_norm': 0.059127070009708405, 'learning_rate': 1.3164059160468496e-05, 'epoch': 1.0259040779687099}
# Step: 4000/11697 | Loss: Calculating... | ETA: 0:33:07 | Progress: 34.20%
# {'eval_loss': 0.006639150436967611, 'eval_accuracy': 0.9725080632775304, 'eval_f1': 0.9719743228432755, 'eval_precision': 0.984147114774889, 'eval_recall': 0.960098979276214, 'eval_runtime': 30.0078, 'eval_samples_per_second': 216.977, 'eval_steps_per_second': 27.126, 'epoch': 1.0259040779687099}
# Step: 4050/11697 | Loss: 0.0056 | ETA: 0:32:57 | Progress: 34.62%
# {'loss': 0.0056, 'grad_norm': 0.2701237201690674, 'learning_rate': 1.3078567153971105e-05, 'epoch': 1.0387278789433187}
# Step: 4100/11697 | Loss: 0.0029 | ETA: 0:32:38 | Progress: 35.05%
# {'loss': 0.0029, 'grad_norm': 0.051154300570487976, 'learning_rate': 1.2993075147473712e-05, 'epoch': 1.0515516799179276}
# Step: 4150/11697 | Loss: 0.0054 | ETA: 0:32:19 | Progress: 35.48%
# {'loss': 0.0054, 'grad_norm': 0.021741727367043495, 'learning_rate': 1.2907583140976322e-05, 'epoch': 1.0643754808925365}
# Step: 4200/11697 | Loss: 0.0060 | ETA: 0:32:01 | Progress: 35.91%
# {'loss': 0.006, 'grad_norm': 0.08280263096094131, 'learning_rate': 1.2822091134478928e-05, 'epoch': 1.0771992818671454}
# Step: 4250/11697 | Loss: 0.0060 | ETA: 0:31:43 | Progress: 36.33%
# {'loss': 0.006, 'grad_norm': 1.0197316408157349, 'learning_rate': 1.2736599127981535e-05, 'epoch': 1.0900230828417543}
# Step: 4300/11697 | Loss: 0.0049 | ETA: 0:31:24 | Progress: 36.76%
# {'loss': 0.0049, 'grad_norm': 0.08360178023576736, 'learning_rate': 1.2651107121484143e-05, 'epoch': 1.1028468838163632}
# Step: 4350/11697 | Loss: 0.0031 | ETA: 0:31:07 | Progress: 37.19%
# {'loss': 0.0031, 'grad_norm': 0.011069826781749725, 'learning_rate': 1.2565615114986748e-05, 'epoch': 1.115670684790972}
# Step: 4400/11697 | Loss: 0.0063 | ETA: 0:30:49 | Progress: 37.62%
# {'loss': 0.0063, 'grad_norm': 0.06222458556294441, 'learning_rate': 1.2480123108489358e-05, 'epoch': 1.128494485765581}
# Step: 4450/11697 | Loss: 0.0041 | ETA: 0:30:31 | Progress: 38.04%
# {'loss': 0.0041, 'grad_norm': 1.4668171405792236, 'learning_rate': 1.2394631101991965e-05, 'epoch': 1.1413182867401899}
# Step: 4500/11697 | Loss: 0.0025 | ETA: 0:30:14 | Progress: 38.47%
# {'loss': 0.0025, 'grad_norm': 0.0121730612590909, 'learning_rate': 1.2309139095494573e-05, 'epoch': 1.1541420877147988}
# Step: 4500/11697 | Loss: Calculating... | ETA: 0:31:10 | Progress: 38.47%
# {'eval_loss': 0.006841388531029224, 'eval_accuracy': 0.9722008908001843, 'eval_f1': 0.9718200217966683, 'eval_precision': 0.9783699059561128, 'eval_recall': 0.965357253325085, 'eval_runtime': 34.7926, 'eval_samples_per_second': 187.137, 'eval_steps_per_second': 23.396, 'epoch': 1.1541420877147988}
# Step: 4550/11697 | Loss: 0.0049 | ETA: 0:31:00 | Progress: 38.90%
# {'loss': 0.0049, 'grad_norm': 0.12006601691246033, 'learning_rate': 1.2223647088997179e-05, 'epoch': 1.1669658886894076}
# Step: 4600/11697 | Loss: 0.0051 | ETA: 0:30:43 | Progress: 39.33%
# {'loss': 0.0051, 'grad_norm': 0.007870133966207504, 'learning_rate': 1.2138155082499788e-05, 'epoch': 1.1797896896640165}
# Step: 4650/11697 | Loss: 0.0035 | ETA: 0:30:24 | Progress: 39.75%
# {'loss': 0.0035, 'grad_norm': 0.4253418743610382, 'learning_rate': 1.2052663076002396e-05, 'epoch': 1.1926134906386252}
# Step: 4700/11697 | Loss: 0.0058 | ETA: 0:30:07 | Progress: 40.18%
# {'loss': 0.0058, 'grad_norm': 0.026382623240351677, 'learning_rate': 1.1967171069505001e-05, 'epoch': 1.205437291613234}
# Step: 4750/11697 | Loss: 0.0045 | ETA: 0:29:50 | Progress: 40.61%
# {'loss': 0.0045, 'grad_norm': 0.0789770558476448, 'learning_rate': 1.1881679063007609e-05, 'epoch': 1.218261092587843}
# Step: 4800/11697 | Loss: 0.0041 | ETA: 0:29:33 | Progress: 41.04%
# {'loss': 0.0041, 'grad_norm': 1.1733782291412354, 'learning_rate': 1.1796187056510218e-05, 'epoch': 1.2310848935624519}
# Step: 4850/11697 | Loss: 0.0048 | ETA: 0:29:16 | Progress: 41.46%
# {'loss': 0.0048, 'grad_norm': 1.9645652770996094, 'learning_rate': 1.1710695050012826e-05, 'epoch': 1.2439086945370608}
# Step: 4900/11697 | Loss: 0.0048 | ETA: 0:28:58 | Progress: 41.89%
# {'loss': 0.0048, 'grad_norm': 0.08021723479032516, 'learning_rate': 1.1625203043515432e-05, 'epoch': 1.2567324955116697}
# Step: 4950/11697 | Loss: 0.0052 | ETA: 0:28:42 | Progress: 42.32%
# {'loss': 0.0052, 'grad_norm': 0.2514599859714508, 'learning_rate': 1.153971103701804e-05, 'epoch': 1.2695562964862785}
# Step: 5000/11697 | Loss: 0.0028 | ETA: 0:28:25 | Progress: 42.75%
# {'loss': 0.0028, 'grad_norm': 0.009390016086399555, 'learning_rate': 1.1454219030520648e-05, 'epoch': 1.2823800974608874}
# Step: 5000/11697 | Loss: Calculating... | ETA: 0:29:06 | Progress: 42.75%
# {'eval_loss': 0.0068693808279931545, 'eval_accuracy': 0.9749654430962986, 'eval_f1': 0.9743104806934594, 'eval_precision': 0.9932519280205655, 'eval_recall': 0.9560779461800185, 'eval_runtime': 30.8479, 'eval_samples_per_second': 211.068, 'eval_steps_per_second': 26.388, 'epoch': 1.2823800974608874}
# Step: 5050/11697 | Loss: 0.0064 | ETA: 0:28:55 | Progress: 43.17%
# {'loss': 0.0064, 'grad_norm': 0.11848969012498856, 'learning_rate': 1.1368727024023254e-05, 'epoch': 1.2952038984354963}
# Step: 5100/11697 | Loss: 0.0051 | ETA: 0:28:38 | Progress: 43.60%
# {'loss': 0.0051, 'grad_norm': 0.3466044068336487, 'learning_rate': 1.1283235017525862e-05, 'epoch': 1.3080276994101052}
# Step: 5150/11697 | Loss: 0.0042 | ETA: 0:28:21 | Progress: 44.03%
# {'loss': 0.0042, 'grad_norm': 0.05547338351607323, 'learning_rate': 1.119774301102847e-05, 'epoch': 1.320851500384714}
# Step: 5200/11697 | Loss: 0.0037 | ETA: 0:28:05 | Progress: 44.46%
# {'loss': 0.0037, 'grad_norm': 0.9174878001213074, 'learning_rate': 1.1112251004531079e-05, 'epoch': 1.3336753013593228}
# Step: 5250/11697 | Loss: 0.0037 | ETA: 0:27:50 | Progress: 44.88%
# {'loss': 0.0037, 'grad_norm': 0.06542809307575226, 'learning_rate': 1.1026758998033685e-05, 'epoch': 1.3464991023339317}
# Step: 5300/11697 | Loss: 0.0034 | ETA: 0:27:34 | Progress: 45.31%
# {'loss': 0.0034, 'grad_norm': 0.8673160672187805, 'learning_rate': 1.0941266991536292e-05, 'epoch': 1.3593229033085406}
# Step: 5350/11697 | Loss: 0.0038 | ETA: 0:27:17 | Progress: 45.74%
# {'loss': 0.0038, 'grad_norm': 0.029866144061088562, 'learning_rate': 1.08557749850389e-05, 'epoch': 1.3721467042831494}
# Step: 5400/11697 | Loss: 0.0034 | ETA: 0:27:00 | Progress: 46.17%
# {'loss': 0.0034, 'grad_norm': 0.30982792377471924, 'learning_rate': 1.0770282978541507e-05, 'epoch': 1.3849705052577583}
# Step: 5450/11697 | Loss: 0.0055 | ETA: 0:26:45 | Progress: 46.59%
# {'loss': 0.0055, 'grad_norm': 0.21923039853572845, 'learning_rate': 1.0684790972044115e-05, 'epoch': 1.3977943062323672}
# Step: 5500/11697 | Loss: 0.0037 | ETA: 0:26:29 | Progress: 47.02%
# {'loss': 0.0037, 'grad_norm': 1.533934473991394, 'learning_rate': 1.0599298965546722e-05, 'epoch': 1.4106181072069761}
# Step: 5500/11697 | Loss: Calculating... | ETA: 0:27:09 | Progress: 47.02%
# {'eval_loss': 0.005586113315075636, 'eval_accuracy': 0.9768084779603747, 'eval_f1': 0.9764025629004532, 'eval_precision': 0.9867340492735313, 'eval_recall': 0.9662851840395917, 'eval_runtime': 34.9839, 'eval_samples_per_second': 186.114, 'eval_steps_per_second': 23.268, 'epoch': 1.4106181072069761}
# Step: 5550/11697 | Loss: 0.0069 | ETA: 0:26:58 | Progress: 47.45%
# {'loss': 0.0069, 'grad_norm': 0.6172519326210022, 'learning_rate': 1.0513806959049332e-05, 'epoch': 1.423441908181585}
# Step: 5600/11697 | Loss: 0.0056 | ETA: 0:26:42 | Progress: 47.88%
# {'loss': 0.0056, 'grad_norm': 0.2443385273218155, 'learning_rate': 1.0428314952551937e-05, 'epoch': 1.436265709156194}
# Step: 5650/11697 | Loss: 0.0038 | ETA: 0:26:26 | Progress: 48.30%
# {'loss': 0.0038, 'grad_norm': 0.3001519441604614, 'learning_rate': 1.0342822946054545e-05, 'epoch': 1.4490895101308028}
# Step: 5700/11697 | Loss: 0.0046 | ETA: 0:26:09 | Progress: 48.73%
# {'loss': 0.0046, 'grad_norm': 0.12160758674144745, 'learning_rate': 1.0257330939557153e-05, 'epoch': 1.4619133111054117}
# Step: 5750/11697 | Loss: 0.0061 | ETA: 0:25:53 | Progress: 49.16%
# {'loss': 0.0061, 'grad_norm': 1.6184196472167969, 'learning_rate': 1.0171838933059758e-05, 'epoch': 1.4747371120800206}
# Step: 5800/11697 | Loss: 0.0053 | ETA: 0:25:38 | Progress: 49.59%
# {'loss': 0.0053, 'grad_norm': 0.8507255911827087, 'learning_rate': 1.0086346926562368e-05, 'epoch': 1.4875609130546295}
# Step: 5850/11697 | Loss: 0.0039 | ETA: 0:25:22 | Progress: 50.01%
# {'loss': 0.0039, 'grad_norm': 0.06117463856935501, 'learning_rate': 1.0000854920064975e-05, 'epoch': 1.5003847140292383}
# Step: 5900/11697 | Loss: 0.0040 | ETA: 0:25:06 | Progress: 50.44%
# {'loss': 0.004, 'grad_norm': 0.08356807380914688, 'learning_rate': 9.915362913567583e-06, 'epoch': 1.5132085150038472}
# Step: 5950/11697 | Loss: 0.0032 | ETA: 0:24:51 | Progress: 50.87%
# {'loss': 0.0032, 'grad_norm': 0.09610859304666519, 'learning_rate': 9.829870907070189e-06, 'epoch': 1.5260323159784561}
# Step: 6000/11697 | Loss: 0.0034 | ETA: 0:24:35 | Progress: 51.30%
# {'loss': 0.0034, 'grad_norm': 1.2957098484039307, 'learning_rate': 9.744378900572798e-06, 'epoch': 1.538856116953065}
# Step: 6000/11697 | Loss: Calculating... | ETA: 0:25:09 | Progress: 51.30%
# {'eval_loss': 0.006001681089401245, 'eval_accuracy': 0.9728152357548764, 'eval_f1': 0.9725112595123466, 'eval_precision': 0.9766063630692452, 'eval_recall': 0.9684503557067738, 'eval_runtime': 36.3945, 'eval_samples_per_second': 178.901, 'eval_steps_per_second': 22.366, 'epoch': 1.538856116953065}
# Step: 6050/11697 | Loss: 0.0038 | ETA: 0:24:58 | Progress: 51.72%
# {'loss': 0.0038, 'grad_norm': 0.3404393792152405, 'learning_rate': 9.658886894075404e-06, 'epoch': 1.551679917927674}
# Step: 6100/11697 | Loss: 0.0061 | ETA: 0:24:42 | Progress: 52.15%
# {'loss': 0.0061, 'grad_norm': 0.7837713956832886, 'learning_rate': 9.573394887578013e-06, 'epoch': 1.5645037189022828}
# Step: 6150/11697 | Loss: 0.0034 | ETA: 0:24:25 | Progress: 52.58%
# {'loss': 0.0034, 'grad_norm': 0.7217021584510803, 'learning_rate': 9.487902881080619e-06, 'epoch': 1.5773275198768915}
# Step: 6200/11697 | Loss: 0.0017 | ETA: 0:24:09 | Progress: 53.01%
# {'loss': 0.0017, 'grad_norm': 0.28298085927963257, 'learning_rate': 9.402410874583228e-06, 'epoch': 1.5901513208515003}
# Step: 6250/11697 | Loss: 0.0034 | ETA: 0:23:53 | Progress: 53.43%
# {'loss': 0.0034, 'grad_norm': 0.5086042284965515, 'learning_rate': 9.316918868085834e-06, 'epoch': 1.6029751218261092}
# Step: 6300/11697 | Loss: 0.0040 | ETA: 0:23:37 | Progress: 53.86%
# {'loss': 0.004, 'grad_norm': 0.0374903678894043, 'learning_rate': 9.231426861588442e-06, 'epoch': 1.6157989228007181}
# Step: 6350/11697 | Loss: 0.0043 | ETA: 0:23:21 | Progress: 54.29%
# {'loss': 0.0043, 'grad_norm': 0.715091347694397, 'learning_rate': 9.145934855091049e-06, 'epoch': 1.628622723775327}
# Step: 6400/11697 | Loss: 0.0026 | ETA: 0:23:05 | Progress: 54.71%
# {'loss': 0.0026, 'grad_norm': 0.009126637130975723, 'learning_rate': 9.060442848593657e-06, 'epoch': 1.641446524749936}
# Step: 6450/11697 | Loss: 0.0038 | ETA: 0:22:50 | Progress: 55.14%
# {'loss': 0.0038, 'grad_norm': 0.014641259796917439, 'learning_rate': 8.974950842096264e-06, 'epoch': 1.6542703257245448}
# Step: 6500/11697 | Loss: 0.0053 | ETA: 0:22:34 | Progress: 55.57%
# {'loss': 0.0053, 'grad_norm': 0.02674809657037258, 'learning_rate': 8.889458835598872e-06, 'epoch': 1.6670941266991535}
# Step: 6500/11697 | Loss: Calculating... | ETA: 0:22:58 | Progress: 55.57%
# {'eval_loss': 0.005059448070824146, 'eval_accuracy': 0.9780371678697589, 'eval_f1': 0.9775756625372433, 'eval_precision': 0.9914122137404581, 'eval_recall': 0.9641200123724095, 'eval_runtime': 29.9408, 'eval_samples_per_second': 217.462, 'eval_steps_per_second': 27.187, 'epoch': 1.6670941266991535}
# Step: 6550/11697 | Loss: 0.0036 | ETA: 0:22:45 | Progress: 56.00%
# {'loss': 0.0036, 'grad_norm': 0.4486595690250397, 'learning_rate': 8.80396682910148e-06, 'epoch': 1.6799179276737624}
# Step: 6600/11697 | Loss: 0.0039 | ETA: 0:22:31 | Progress: 56.42%
# {'loss': 0.0039, 'grad_norm': 0.6443394422531128, 'learning_rate': 8.718474822604087e-06, 'epoch': 1.6927417286483712}
# Step: 6650/11697 | Loss: 0.0045 | ETA: 0:22:15 | Progress: 56.85%
# {'loss': 0.0045, 'grad_norm': 0.08594364672899246, 'learning_rate': 8.632982816106694e-06, 'epoch': 1.7055655296229801}
# Step: 6700/11697 | Loss: 0.0024 | ETA: 0:21:59 | Progress: 57.28%
# {'loss': 0.0024, 'grad_norm': 0.04026172682642937, 'learning_rate': 8.547490809609302e-06, 'epoch': 1.718389330597589}
# Step: 6750/11697 | Loss: 0.0043 | ETA: 0:21:44 | Progress: 57.71%
# {'loss': 0.0043, 'grad_norm': 0.7462210655212402, 'learning_rate': 8.46199880311191e-06, 'epoch': 1.731213131572198}
# Step: 6800/11697 | Loss: 0.0040 | ETA: 0:21:28 | Progress: 58.13%
# {'loss': 0.004, 'grad_norm': 0.06956205517053604, 'learning_rate': 8.376506796614517e-06, 'epoch': 1.7440369325468068}
# Step: 6850/11697 | Loss: 0.0037 | ETA: 0:21:13 | Progress: 58.56%
# {'loss': 0.0037, 'grad_norm': 0.6896258592605591, 'learning_rate': 8.291014790117125e-06, 'epoch': 1.7568607335214157}
# Step: 6900/11697 | Loss: 0.0044 | ETA: 0:20:57 | Progress: 58.99%
# {'loss': 0.0044, 'grad_norm': 0.10275806486606598, 'learning_rate': 8.205522783619732e-06, 'epoch': 1.7696845344960246}
# Step: 6950/11697 | Loss: 0.0035 | ETA: 0:20:42 | Progress: 59.42%
# {'loss': 0.0035, 'grad_norm': 0.0540100522339344, 'learning_rate': 8.12003077712234e-06, 'epoch': 1.7825083354706335}
# Step: 7000/11697 | Loss: 0.0039 | ETA: 0:20:27 | Progress: 59.84%
# {'loss': 0.0039, 'grad_norm': 0.04428671672940254, 'learning_rate': 8.034538770624947e-06, 'epoch': 1.7953321364452424}
# Step: 7000/11697 | Loss: Calculating... | ETA: 0:20:49 | Progress: 59.84%
# {'eval_loss': 0.005547657143324614, 'eval_accuracy': 0.9754262018123177, 'eval_f1': 0.9749530369442705, 'eval_precision': 0.9870047543581616, 'eval_recall': 0.9631920816579029, 'eval_runtime': 32.8232, 'eval_samples_per_second': 198.366, 'eval_steps_per_second': 24.8, 'epoch': 1.7953321364452424}
# Step: 7050/11697 | Loss: 0.0063 | ETA: 0:20:37 | Progress: 60.27%
# {'loss': 0.0063, 'grad_norm': 0.18013542890548706, 'learning_rate': 7.949046764127555e-06, 'epoch': 1.8081559374198513}
# Step: 7100/11697 | Loss: 0.0018 | ETA: 0:20:22 | Progress: 60.70%
# {'loss': 0.0018, 'grad_norm': 0.022873548790812492, 'learning_rate': 7.863554757630163e-06, 'epoch': 1.8209797383944601}
# Step: 7150/11697 | Loss: 0.0037 | ETA: 0:20:06 | Progress: 61.13%
# {'loss': 0.0037, 'grad_norm': 0.022977221757173538, 'learning_rate': 7.77806275113277e-06, 'epoch': 1.833803539369069}
# Step: 7200/11697 | Loss: 0.0057 | ETA: 0:19:51 | Progress: 61.55%
# {'loss': 0.0057, 'grad_norm': 0.025804437696933746, 'learning_rate': 7.692570744635378e-06, 'epoch': 1.846627340343678}
# Step: 7250/11697 | Loss: 0.0045 | ETA: 0:19:35 | Progress: 61.98%
# {'loss': 0.0045, 'grad_norm': 0.05113194137811661, 'learning_rate': 7.607078738137985e-06, 'epoch': 1.8594511413182868}
# Step: 7300/11697 | Loss: 0.0050 | ETA: 0:19:20 | Progress: 62.41%
# {'loss': 0.005, 'grad_norm': 0.01930239237844944, 'learning_rate': 7.521586731640592e-06, 'epoch': 1.8722749422928957}
# Step: 7350/11697 | Loss: 0.0050 | ETA: 0:19:05 | Progress: 62.84%
# {'loss': 0.005, 'grad_norm': 0.06282207369804382, 'learning_rate': 7.4360947251431995e-06, 'epoch': 1.8850987432675046}
# Step: 7400/11697 | Loss: 0.0024 | ETA: 0:18:50 | Progress: 63.26%
# {'loss': 0.0024, 'grad_norm': 0.059363797307014465, 'learning_rate': 7.350602718645807e-06, 'epoch': 1.8979225442421135}
# Step: 7450/11697 | Loss: 0.0042 | ETA: 0:18:35 | Progress: 63.69%
# {'loss': 0.0042, 'grad_norm': 0.40526923537254333, 'learning_rate': 7.265110712148415e-06, 'epoch': 1.9107463452167224}
# Step: 7500/11697 | Loss: 0.0035 | ETA: 0:18:19 | Progress: 64.12%
# {'loss': 0.0035, 'grad_norm': 0.041132185608148575, 'learning_rate': 7.179618705651022e-06, 'epoch': 1.9235701461913313}
# Step: 7500/11697 | Loss: Calculating... | ETA: 0:18:37 | Progress: 64.12%
# {'eval_loss': 0.005917702801525593, 'eval_accuracy': 0.9766548917217017, 'eval_f1': 0.9761755485893417, 'eval_precision': 0.9895138226882746, 'eval_recall': 0.9631920816579029, 'eval_runtime': 31.4537, 'eval_samples_per_second': 207.003, 'eval_steps_per_second': 25.879, 'epoch': 1.9235701461913313}
# Step: 7500/11697 | Loss: Calculating... | ETA: 0:18:41 | Progress: 64.12%
# {'train_runtime': 2004.7102, 'train_samples_per_second': 93.347, 'train_steps_per_second': 5.835, 'train_loss': 0.006919148644804954, 'epoch': 1.9235701461913313}
# TrainOutput(global_step=7500, training_loss=0.006919148644804954, metrics={'train_runtime': 2004.7102, 'train_samples_per_second': 93.347, 'train_steps_per_second': 5.835, 'train_loss': 0.006919148644804954, 'epoch': 1.9235701461913313})

# %% [markdown]
# 7. FINAL SAVE

# %%
final_path = os.path.join(OUTPUT_DIR, "final_muril")
trainer.save_model(final_path)
tokenizer.save_pretrained(final_path)

print(f"\nMuRIL finetuning complete! Saved to: {final_path}")
# Out:
# MuRIL finetuning complete! Saved to: D:\Major Project\SpamX\machine_learning\models\MuRIL\final_muril
