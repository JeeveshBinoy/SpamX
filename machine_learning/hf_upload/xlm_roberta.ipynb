# %%
import os
from huggingface_hub import HfApi, login
import getpass

# %%
token = getpass.getpass("Enter your Hugging Face WRITE token: ")
login(token)
api = HfApi()
repo_id = "SpamX/XLM_RoBERTa"

# %%
local_model_path = r"D:\Major Project\SpamX\machine_learning\models\XLM_Roberta\final_xlm_roberta_calibrated1"

print(f"Preparing to upload from: {local_model_path}")

try:
    api.create_repo(repo_id=repo_id, repo_type="model", exist_ok=True)

    api.upload_folder(
        folder_path=local_model_path,
        repo_id=repo_id,
        repo_type="model",
        commit_message="Initial upload of fine-tuned XLM RoBERTa for Malayalam/English Spam Detection",
        ignore_patterns=["*.git*", "checkpoint-*"]
    )
    
    print(f"\nSuccess! Your model is live at: https://huggingface.co/{repo_id}")

except Exception as e:
    print(f"\nError: {e}")
# Out:
# Preparing to upload from: D:\Major Project\SpamX\machine_learning\models\XLM_Roberta\final_xlm_roberta_calibrated1
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Success! Your model is live at: https://huggingface.co/SpamX/XLM_RoBERTa

# %%
import os
from huggingface_hub import HfApi, login
import getpass

# %%
token = getpass.getpass("Enter your Hugging Face WRITE token: ")
login(token)
api = HfApi()
repo_id = "SpamX/XLM_RoBERTa_V2"

# %%
local_model_path = r"D:\Major Project\SpamX\machine_learning\models\XLM_Roberta\final_xlm_roberta_calibrated1_v2"

print(f"Preparing to upload from: {local_model_path}")

try:
    api.create_repo(repo_id=repo_id, repo_type="model", exist_ok=True)

    api.upload_folder(
        folder_path=local_model_path,
        repo_id=repo_id,
        repo_type="model",
        commit_message="Upload of fine-tuned XLM RoBERTa for Malayalam/English Spam Detection",
        ignore_patterns=["*.git*", "checkpoint-*"]
    )
    
    print(f"\nSuccess! Your model is live at: https://huggingface.co/{repo_id}")

except Exception as e:
    print(f"\nError: {e}")
# Out:
# Preparing to upload from: D:\Major Project\SpamX\machine_learning\models\XLM_Roberta\final_xlm_roberta_calibrated1_v2
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Success! Your model is live at: https://huggingface.co/SpamX/XLM_RoBERTa_V2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
